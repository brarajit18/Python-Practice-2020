# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\ajitp\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('credit_test.csv')

# %%
sales = pd.read_csv('superstore_dataset2011-2015.csv', encoding="ISO-8859-1")

# %%
sales.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
sns.lineplot(x=sales['Order Date'], y=sales['Sales'])

# %%
sales['Order Date']
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    31-12-2014
# 51286    31-12-2014
# 51287    31-12-2014
# 51288    31-12-2014
# 51289    31-12-2014
# Name: Order Date, Length: 51290, dtype: object

# %%
sales.head(50)
# Out:
#     Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0    42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1    22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2    48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3    11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4    22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 5    22254    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 6    21613    IN-2011-30733   1/2/2011  3/2/2011    Second Class    PO-18865
# 7    34662   CA-2011-115161   1/2/2011  3/2/2011     First Class    LC-17050
# 8    44508     AO-2011-1390   1/2/2011  4/2/2011    Second Class     DK-3150
# 9    23688    ID-2011-56493   1/2/2011  3/2/2011    Second Class    SP-20650
# 10   25293    IN-2011-36074   1/2/2011  5/2/2011    Second Class    DK-13150
# ...

# %%
sales['Order Date'].to_csv("dates_column.csv")

# %%
sales['Order Date'][0] #MM/DD/YYYY
# Out:
# '1/1/2011'

# %%
type(sales['Order Date'][0])
# Out:
# str

# %%
d1 = sales['Order Date'][0]
d1 = d1[-4:]
d1
# Out:
# '2011'

# %%
years_list = []
for d1 in sales['Order Date']:
    y1 = d1[-4:]
    years_list.append(y1)

# %%
pd.Series(years_list).to_csv("Years_List.csv")

# %%
my_date = sales['Order Date'][0].split('/') # '/' delimiter
my_date
# Out:
# ['1', '1', '2011']

# %%
int(my_date[0])
# Out:
# 1

# %%
months = []
for dd in sales['Order Date']:
    my_date = dd.split('/')
    month_value = my_date[0]
    months.append(month_value)

# %%
pd.Series(months).to_csv("months_values.csv")

# %%
date1 = '17-12-2012' #dd/mm/yyyy

# %%
date1.split('-')
# Out:
# ['17', '12', '2012']

# %%
date1.find('/')
# Out:
# -1

# %%
date1.replace('-','/')
# Out:
# '17/12/2012'

# %%
date1.find

# %%
def extractMonth(date_value):
    # This function take the date as input
    # and split the date by delimiting character.
    # In this data, we have two types of date formats.
    # Type A: MM/DD/YYYY
    # Type B: DD-MM-YYYY
    if date_value.find('-') == -1: # Type A
        my_date = date_value.split('/')
        month_value = my_date[0]
    else: # Type B
        my_date = date_value.split('-')
        month_value = my_date[1]
    return month_value

# %%
months = []
for dd in sales['Order Date']:
    month_value = extractMonth(dd)
    months.append(month_value)

# %%
# Assume you have a data from 2011 to 2020
# Before 2016, your company was using Software Simpli_Accounting (2011-2015)
# 2016 onwards, your company started using different accounting software (2016-2020)

# %%
def extractYear(date_value):
    # This function take the date as input
    # and split the date by delimiting character.
    # In this data, we have two types of date formats.
    # Type A: MM/DD/YYYY
    # Type B: DD-MM-YYYY
    if date_value.find('-') == -1: #Type A
        my_date = date_value.split('/')
        year_value = my_date[2]
    else: #Type B
        my_date = date_value.split('-')
        year_value = my_date[2]
    return year_value

# %%
years = []
for dd in sales['Order Date']:
    years_value = extractYear(dd)
    years.append(years_value)

# %%
sales['month_name'] = months

# %%
sales['year'] = years

# %%
sales['year_number'] = years_list

# %%
type(sales['month_name'][0])
# Out:
# str

# %%
type(sales['year'][0])
# Out:
# str

# %%
type(sales['year_number'][0])
# Out:
# str

# %%
idx = 0
for year_num in sales['year_number']:
    if isinstance(year_num, str) == False:
        print (idx)
    idx += 1

# %%
idx = 0
for year_num in sales['year_number']:
    print (type(year_num))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
# data validation, data verification, data quality checking

# %%
sales[['Order Date','month_name','year', 'year_number']].to_excel("Data_Validation_2_Month_Year_YearNumber_Extraction.xls")

# %%
sales.head(5)
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#   Sub-Category                 Product Name    Sales Quantity Discount  \
# ...

# %%
sales_year_and_month_wise = sales.groupby(['year','month_name'])['Sales'].sum()

# %%
sales_year_and_month_wise
# Out:
# year  month_name
# 2011  01             56073.27304
#       02             55399.87516
#       03             91185.21694
#       04             64700.29980
#       05             92069.03558
#                         ...
# 2014  5             120547.39026
#       6             123589.07212
#       7             130736.64412
#       8             148774.54264
#       9             130701.28754
# Name: Sales, Length: 84, dtype: float64

# %%
sales_year_and_month_wise.index
# Out:
# MultiIndex([('2011',  '1'),
#             ('2011', '10'),
#             ('2011', '11'),
#             ('2011', '12'),
#             ('2011',  '2'),
#             ('2011',  '3'),
#             ('2011',  '4'),
#             ('2011',  '5'),
#             ('2011',  '6'),
#             ('2011',  '7'),
#             ('2011',  '8'),
#             ('2011',  '9'),
#             ('2012',  '1'),
#             ('2012', '10'),
#             ('2012', '11'),
#             ('2012', '12'),
#             ('2012',  '2'),
#             ('2012',  '3'),
#             ('2012',  '4'),
#             ('2012',  '5'),
#             ('2012',  '6'),
#             ('2012',  '7'),
#             ('2012',  '8'),
#             ('2012',  '9'),
#             ('2013',  '1'),
#             ('2013', '10'),
#             ('2013', '11'),
#             ('2013', '12'),
#             ('2013',  '2'),
#             ('2013',  '3'),
#             ('2013',  '4'),
#             ('2013',  '5'),
#             ('2013',  '6'),
# ...

# %%
sales_year_and_month_wise.values
# Out:
# array([ 56073.27304,  55399.87516,  91185.21694,  64700.2998 ,
#         92069.03558, 121334.95786,  81077.61916, 113438.62902,
#        179887.0319 ,  82168.02738, 204675.07846, 214934.29386,
#        292359.96752,  79570.0657 ,  80270.37678,  64133.17054,
#         56077.68534,  68003.4818 ,  80957.0784 , 105784.86622,
#         75350.86508,  81078.80734,  57251.4492 , 111225.91528,
#        111162.57024, 131750.04178, 164292.15054,  83723.11036,
#        192638.73002, 186263.65254,  81722.08604, 239321.09904,
#        270723.05356, 291972.33306,  95409.70224,  90382.81256,
#         76307.39168,  87210.11864,  84997.62118,  90670.91772,
#         79030.93084,  70304.20054, 106479.79284,  83815.8305 ,
#        112787.36446, 102321.48812, 178820.4915 , 235309.24404,
#        128671.67948, 221961.04208, 229918.25934,  99979.40298,
#        270121.8757 , 383039.21248, 371245.4088 , 107246.94166,
#        117760.43022, 130859.86032, 125689.47186, 105853.09966,
# ...

# %%
index_list = sales_year_and_month_wise.index.to_list()

# %%
custom_index = []
for year, month in index_list:
    custom_index.append(year+'-'+month)

# %%
custom_index
# Out:
# ['2011-01',
#  '2011-02',
#  '2011-03',
#  '2011-04',
#  '2011-05',
#  '2011-06',
#  '2011-07',
#  '2011-08',
#  '2011-09',
#  '2011-1',
#  '2011-10',
#  '2011-11',
#  '2011-12',
#  '2011-2',
#  '2011-3',
#  '2011-4',
#  '2011-5',
#  '2011-6',
#  '2011-7',
#  '2011-8',
#  '2011-9',
#  '2012-01',
#  '2012-02',
#  '2012-03',
#  '2012-04',
#  '2012-05',
#  '2012-06',
#  '2012-07',
#  '2012-08',
#  '2012-09',
#  '2012-1',
#  '2012-10',
#  '2012-11',
#  '2012-12',
#  '2012-2',
#  '2012-3',
#  '2012-4',
#  '2012-5',
#  '2012-6',
#  '2012-7',
#  '2012-8',
#  '2012-9',
#  '2013-01',
#  '2013-02',
#  '2013-03',
#  '2013-04',
#  '2013-05',
#  '2013-06',
#  '2013-07',
#  '2013-08',
#  '2013-09',
#  '2013-1',
#  '2013-10',
#  '2013-11',
#  '2013-12',
#  '2013-2',
#  '2013-3',
#  '2013-4',
#  '2013-5',
#  '2013-6',
#  '2013-7',
#  '2013-8',
#  '2013-9',
#  '2014-01',
#  '2014-02',
#  '2014-03',
#  '2014-04',
#  '2014-05',
#  '2014-06',
#  '2014-07',
#  '2014-08',
#  '2014-09',
#  '2014-1',
# ...

# %%
plt.figure(figsize=(16, 3))
sns.lineplot(x=custom_index, y=sales_year_and_month_wise)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 3))
sns.barplot(x=custom_index, y=sales_year_and_month_wise)
plt.xticks(rotation=90)
plt.show()

# %%
sales_values = sales_year_and_month_wise.values

# %%
sales_values[sales_values>7851537] = 0 # don't need these things now, because error is corrected

# %%
sales_values
# Out:
# array([ 56073.27304,  55399.87516,  91185.21694,  64700.2998 ,
#         92069.03558, 121334.95786,  81077.61916, 113438.62902,
#        179887.0319 ,  82168.02738, 204675.07846, 214934.29386,
#        292359.96752,  79570.0657 ,  80270.37678,  64133.17054,
#         56077.68534,  68003.4818 ,  80957.0784 , 105784.86622,
#         75350.86508,  81078.80734,  57251.4492 , 111225.91528,
#        111162.57024, 131750.04178, 164292.15054,  83723.11036,
#        192638.73002, 186263.65254,  81722.08604, 239321.09904,
#        270723.05356, 291972.33306,  95409.70224,  90382.81256,
#         76307.39168,  87210.11864,  84997.62118,  90670.91772,
#         79030.93084,  70304.20054, 106479.79284,  83815.8305 ,
#        112787.36446, 102321.48812, 178820.4915 , 235309.24404,
#        128671.67948, 221961.04208, 229918.25934,  99979.40298,
#        270121.8757 , 383039.21248, 371245.4088 , 107246.94166,
#        117760.43022, 130859.86032, 125689.47186, 105853.09966,
# ...

# %%
plt.figure(figsize=(16, 3))
sns.barplot(x=custom_index, y=sales_values)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 3))
sns.lineplot(x=custom_index, y=sales_values)
plt.xticks(rotation=90)
plt.show()

# %%
# Statement: Outliers supress the long-terms trends. 
# So it becomes normal to remove the outlier values and visualize rest of the trend.
# However, thats avoding some specific unit, that would give you an overall trend for normal data.
# just by avoiding outlying data (outliers)

# %%
sales.head(5)
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#   Sub-Category                 Product Name    Sales Quantity Discount  \
# ...

# %%
data2012 = sales.loc[(sales['year']=='2012')]

# %%
data12_2012 = data2012.loc[data2012['month_name']=='12']

# %%
data12_2012.to_excel("data_12-2020.xls")

# %%
dat2012 = sales.loc[sales['year_number']=='2012']
dat12_2012 = dat2012.loc[data2012['month_name']=='12']
dat12_2012.to_excel("dat_12-2020.xls")
