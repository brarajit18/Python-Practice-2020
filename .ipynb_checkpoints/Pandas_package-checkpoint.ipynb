# %%
import pandas as pd

# %%
# Panel Data (PanDaS)

# %%
# CSV = Comma Separated values

# %%
data = pd.read_csv('student-mat.csv', delimiter=';')

# %%
data.head() # Top 5 rows of data
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data2 = pd.read_csv('student-mat2.csv')

# %%
data2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Unnamed: 26  Dalc  Walc health absences  G1  G2  G3
# 0        3     4            1     1     3      6        5   6   6 NaN
# 1        3     3            1     1     3      4        5   5   6 NaN
# 2        3     2            2     3     3     10        7   8  10 NaN
# 3        2     2            1     1     5      2       15  14  15 NaN
# 4        3     2            1     2     5      4        6  10  10 NaN
#
# [5 rows x 34 columns]

# %%
data2.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... freetime goout  Unnamed: 26  Dalc  Walc health absences  G1  G2  G3
# 0  ...        3     4            1     1     3      6        5   6   6 NaN
# ...

# %%
data2.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   freetime goout  Unnamed: 26  Dalc  Walc health absences G1 G2  G3
# 0        3     4            1     1     3      6        5  6  6 NaN
# 1        3     3            1     1     3      4        5  5  6 NaN
#
# [2 rows x 34 columns]

# %%
data2.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... freetime goout  Unnamed: 26  Dalc  Walc health absences  G1  G2  G3
# 390  ...        5     4            4     5     4     11        9   9   9 NaN
# 391  ...        4     5            3     4     2      3       14  16  16 NaN
# 392  ...        5     3            3     3     3      3       10   8   7 NaN
# 393  ...        4     1            3     4     5      0       11  12  10 NaN
# 394  ...        2     3            3     3     5      5        8   9   9 NaN
#
# [5 rows x 34 columns]

# %%
data2.tail(100)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 295     GP   M   17       U     GT3       T     3     3    health     other
# 296     GP   F   19       U     GT3       T     4     4    health     other
# 297     GP   F   18       U     LE3       T     4     3     other     other
# 298     GP   F   18       U     GT3       T     4     3     other     other
# 299     GP   M   18       U     LE3       T     4     4   teacher   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
data2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
data2['school']
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
type(data2['school'])
# Out:
# pandas.core.series.Series

# %%
data2['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
data2.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
data2.groupby('school')['age'].count() #groupby(column name)[any random colum].count()
# Out:
# school
# GP    349
# MS     46
# Name: age, dtype: int64

# %%
data2.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout',
#        'Unnamed: 26', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
len(data2.columns)
# Out:
# 34

# %%
data2.shape
# Out:
# (395, 34)

# %%
data2.groupby('school')['traveltime'].mean()
# Out:
# school
# GP    1.386819
# MS    1.913043
# Name: traveltime, dtype: float64

# %%
data2.groupby(['school', 'traveltime'])['age'].count() # count = count of rows
# Out:
# school  traveltime
# GP      1             243
#         2              84
#         3              15
#         4               7
# MS      1              14
#         2              23
#         3               8
#         4               1
# Name: age, dtype: int64

# %%
report1 = data2.groupby('school')['age'].count()

# %%
report1.to_csv('Student Count in Each School.csv')

# %%
report2 = data2.groupby(['school', 'traveltime'])['age'].count()

# %%
report2.to_csv('Student Travel Time for each school.csv')

# %%
students = pd.Series(['John','Jake','Marie','Maggie'])

# %%
traveltime = pd.Series([15, 10, 5, 30])

# %%
students
# Out:
# 0      John
# 1      Jake
# 2     Marie
# 3    Maggie
# dtype: object

# %%
traveltime
# Out:
# 0    15
# 1    10
# 2     5
# 3    30
# dtype: int64

# %%
df = pd.DataFrame({'student': students, 'tarveltime': traveltime})

# %%
df
# Out:
#   student  tarveltime
# 0    John          15
# 1    Jake          10
# 2   Marie           5
# 3  Maggie          30

# %%
df['count'] = 1

# %%
df
# Out:
#   student  tarveltime  count
# 0    John          15      1
# 1    Jake          10      1
# 2   Marie           5      1
# 3  Maggie          30      1

# %%
data2['count'] = 1

# %%
report2 = data2.groupby(['school', 'traveltime'])['count'].count()

# %%
report2.to_csv('Student Travel Time 2.csv')

# %%
data2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   goout Unnamed: 26  Dalc  Walc  health absences  G1  G2  G3 count
# 0     4           1     1     3       6        5   6   6 NaN     1
# 1     3           1     1     3       4        5   5   6 NaN     1
# 2     2           2     3     3      10        7   8  10 NaN     1
# 3     2           1     1     5       2       15  14  15 NaN     1
# 4     2           1     2     5       4        6  10  10 NaN     1
#
# [5 rows x 35 columns]

# %%
data2.groupby(['school'])['absences'].mean()
# Out:
# school
# GP    10.939828
# MS    10.673913
# Name: absences, dtype: float64

# %%
data2.groupby(['school', 'sex'])['absences'].mean()
# Out:
# school  sex
# GP      F      10.579235
#         M      11.337349
# MS      F      10.920000
#         M      10.380952
# Name: absences, dtype: float64

# %%
data2.groupby(['school', 'sex'])['age'].mean()
# Out:
# school  sex
# GP      F      16.579235
#         M      16.457831
# MS      F      17.840000
#         M      18.238095
# Name: age, dtype: float64

# %%
data2['age'].mean()
# Out:
# 16.696202531645568

# %%
data2['age'].median()
# Out:
# 17.0

# %%
data2['age'].std()
# Out:
# 1.2760427246056245

# %%
import numpy as np

# %%
age = np.array(data2['age'])

# %%
np.mean(age)
# Out:
# 16.696202531645568

# %%
np.std(age)
# Out:
# 1.2744264570480206

# %%
data2['age'].plot(kind='hist') # Frequency Distribution plot with Pandas
